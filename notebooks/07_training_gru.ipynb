# %% [markdown]
# ## Objective
#
# Training CNN + GRU (Baseline).

# %% [markdown]
# ## Theory
#
# Explain the ML concept behind this step.

# %%
# Imports

# %%
# Configuration

# %%
# Implementation

# %%
# Visualization

# %% [markdown]
# ## Observation
#
# Analyse the result.

# %%
# Export / Save outputs

# %% [markdown]
# ## Next Step
#
# What to do in the next notebook.
